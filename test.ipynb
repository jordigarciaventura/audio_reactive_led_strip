# %%
import numpy as np
import matplotlib.pyplot as plt
import wave

with wave.open("sample.wav", "r") as wav_file:
    while True:

        buffer = wav_file.readframes(44100)
        data = np.frombuffer(buffer, dtype='int16')

        fft_spectrum = np.fft.rfft(data)
        freq = np.fft.rfftfreq(len(data), 1./44100)
        fft_spectrum_abs = np.abs(fft_spectrum)

        # plot
        fig, [ax1, ax2] = plt.subplots(nrows=2, ncols=1)
        ax1.plot(range(len(data)),data , ".-")
        # ax2.plot(freq, fft_spectrum_abs, '.-')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_53700/3036915484.py in <module>
#      17         ax1.plot(range(len(data)),data , ".-")
#      18         # ax2.plot(freq, fft_spectrum_abs, '.-')
# ---> 19         plt.show()
#      20
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# ~/.local/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# construct a time signal
fs = 2000
tstep = 1 / fs
f0 = 100

N = int(10*fs / f0)

t = np.linspace(0, (N-1)*tstep, N)
fstep = fs / N
f = np.linspace(0, (N-1)*fstep, N)

y = 1 * np.sin(2* np.pi * f0*t)

#perform fft
f_plot = np.fft.rfftfreq(len(y), 1./N)
x_mag_plot = np.abs(np.fft.rfft(y))/N*2

# plot
fig, [ax1, ax2] = plt.subplots(nrows=2, ncols=1)
ax1.plot(t, y, ".-")
ax2.plot(f_plot, x_mag_plot, '.-')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# construct a time signal
fs = 2000
tstep = 1 / fs
f0 = 100

N = int(1*fs / f0)

t = np.linspace(0, (N-1)*tstep, N)
fstep = fs / N
f = np.linspace(0, (N-1)*fstep, N)

y = 1 * np.sin(2* np.pi * f0*t)

#perform fft
x = np.fft.fft(y)
# x_mag = np.abs(x) / len(y)
x_mag = np.abs(x) / N

f_plot = f[0:int(N/2+1)]
x_mag_plot = 2*x_mag[0:int(N/2+1)]
x_mag_plot[0] /= 2


# plot
fig, [ax1, ax2] = plt.subplots(nrows=2, ncols=1)
ax1.plot(t, y, ".-")
ax2.plot(f_plot, x_mag_plot, '.-')
plt.show()
